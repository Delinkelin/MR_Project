# %%
import pandas as pd
movies = pd.read_csv("movies.csv",encoding="Latin1")
Ratings = pd.read_csv("ratings.csv")
# Tags = pd.read_csv("tags.csv",encoding="Latin1")
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings = pd.merge(movies,Ratings)
print(ratings.shape)
ratings.head()
UserRatings = ratings.pivot_table(index=['userId'],columns=['title'],values='rating').fillna(2.5, axis=1)
UserRatings.head()
print("Before: ",UserRatings.shape)
# UserRatings = UserRatings.dropna(thresh=10, axis=1).fillna(0,axis=1)
#userRatings.fillna(0, inplace=True)
# print("After: ",UserRatings.shape)
# Out:
# (99549, 5)
# Before:  (671, 8854)

# %%
UserRatings
# Out:
# title   $9.99 (2008)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1                2.5                                      2.5
# 2                2.5                                      2.5
# 3                2.5                                      2.5
# 4                2.5                                      2.5
# 5                2.5                                      2.5
# ...              ...                                      ...
# 667              2.5                                      2.5
# 668              2.5                                      2.5
# 669              2.5                                      2.5
# 670              2.5                                      2.5
# 671              2.5                                      2.5
#
# title   'Neath the Arizona Skies (1934)  'Round Midnight (1986)  \
# userId
# 1                                   2.5                     2.5
# 2                                   2.5                     2.5
# ...

# %%
corrMatrix = UserRatings.corr(method='pearson')
# print(corrMatrix.head(10))
import pickle
pickle.dump(corrMatrix, open('corrMatrix.pkl', 'wb'))
def get_similar(movie_name,rating):
    similar_ratings = corrMatrix[movie_name]*(rating-2.5)
    similar_ratings = similar_ratings.sort_values(ascending=False)
    #print(type(similar_ratings))
    return similar_ratings

# %%
# corrMatrix.shape()

# %%
romantic_movies= {"Interstellar (2014)":5, "Avengers, The (2012)":5, "Inception (2010)": 4}
similar_movies = pd.DataFrame()
for movie,rating in romantic_movies.items():
    similar_movies = similar_movies.append(get_similar(movie,rating),ignore_index = True)
similar_movies.head(10)
x= []
print(similar_movies.sum().head(20))
xz = similar_movies.sum()
for y in similar_movies.sum().sort_values(ascending=False).head(20).index:
    if y not in romantic_movies:
        x.append(y)
# print(type(xz))
x
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Avengers, The (2012)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-6cd66ea9da2c> in <module>
# ...
